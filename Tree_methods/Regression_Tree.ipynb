# %%
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ISLP import load_data

data = load_data('OJ')


data['Store7'] = [1 if d == 'Yes' else 0 for d in data['Store7']]
y = data['Purchase']
X = data.drop('Purchase', axis=1)

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

x_train
# Out:
#       WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  SpecialCH  \
# 442              258        1     1.76     2.18    0.00    0.00          0
# 464              265        7     1.86     2.13    0.37    0.00          1
# 504              244        3     1.99     2.23    0.00    0.00          0
# 732              276        4     2.09     2.09    0.20    0.40          0
# 388              233        2     1.69     1.69    0.00    0.00          0
# ...              ...      ...      ...      ...     ...     ...        ...
# 330              262        1     1.76     1.99    0.00    0.40          0
# 466              269        7     1.86     2.13    0.27    0.00          1
# 121              261        1     1.76     1.99    0.00    0.00          0
# 1044             241        1     1.86     1.99    0.00    0.30          0
# 860              274        7     1.86     2.13    0.47    0.54          1
#
#       SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff  Store7  \
# 442           0  0.733760         2.18         1.76       0.42       0
# 464           0  0.733760         2.13         1.49       0.64       1
# 504           0  0.754240         2.23         1.99       0.24       0
# 732           0  0.320000         1.69         1.89      -0.20       0
# 388           0  0.105838         1.69         1.69       0.00       0
# ...         ...       ...          ...          ...        ...     ...
# 330           1  0.500000         1.59         1.76      -0.17       0
# 466           0  0.829606         2.13         1.59       0.54       1
# 121           0  0.967444         1.99         1.76       0.23       0
# 1044          1  0.777178         1.69         1.86      -0.17       0
# 860           0  0.978010         1.59         1.39       0.20       1
#
#       PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 442    0.000000   0.000000           0.42      1
# 464    0.000000   0.198925           0.27      0
# 504    0.000000   0.000000           0.24      3
# 732    0.191388   0.095694           0.00      4
# 388    0.000000   0.000000           0.00      2
# ...         ...        ...            ...    ...
# 330    0.201005   0.000000           0.23      1
# 466    0.000000   0.145161           0.27      0
# 121    0.000000   0.000000           0.23      1
# 1044   0.150754   0.000000           0.13      1
# 860    0.253521   0.252688           0.27      0
#
# [749 rows x 17 columns]

# %% [markdown]
# # Feature Correlation

# %%
names = x_train.columns
df_features = pd.DataFrame(x_train, columns=names)

corr_mtx = df_features.corr(method='pearson')
plt.matshow(corr_mtx, cmap="RdBu_r")
plt.colorbar()

plt.xticks(range(len(names)), names, rotation=90)
plt.yticks(range(len(names)), names)
plt.grid(False)
plt.show()
