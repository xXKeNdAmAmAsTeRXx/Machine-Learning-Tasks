# %% [markdown]
# # Coef Analysis of linear Regression

# %%
# imports
import pandas as pd

# %% [markdown]
# ## Getting Data

# %%
data = pd.read_csv('new_Exam_Score_Prediction.csv')

y = data['exam_score']
X = data.drop('exam_score', axis=1)

data
# Out:
#        age  gender  study_hours  class_attendance  internet_access  \
# 0       17       1         2.78              92.9                1
# 1       22       1         7.88              76.8                1
# 2       20       0         0.89              71.6                1
# 3       23       1         3.48              65.4                1
# 4       17       0         1.35              69.0                1
# ...    ...     ...          ...               ...              ...
# 13269   17       1         5.74              81.4                1
# 13270   19       0         3.28              73.3                1
# 13271   18       1         3.71              41.6                0
# 13272   19       1         4.60              76.3                0
# 13273   20       1         7.50              47.9                1
#
#        sleep_hours  sleep_quality  facility_rating  exam_difficulty  \
# 0              7.4              0                0                2
# 1              8.5              0                2                1
# 2              9.8              0                0                1
# 3              4.2              2                0                1
# 4              7.4              1                2                2
# ...            ...            ...              ...              ...
# 13269          7.5              2                2                2
# 13270          9.5              2                2                0
# 13271          5.9              1                1                1
# 13272          6.1              2                1                1
# 13273          7.5              0                1                1
#
#        exam_score  diploma  group_study  self_study  online_videos  coaching  \
# 0            58.9        1            0           0              0         1
# 1            90.3        0            0           0              0         1
# 2            43.7        1            0           0              0         1
# 3            58.2        0            0           0              0         0
# 4            53.7        0            0           0              1         0
# ...           ...      ...          ...         ...            ...       ...
# 13269        95.0        0            0           0              1         0
# 13270        93.9        0            1           0              0         0
# 13271        60.9        0            0           0              0         1
# 13272        79.0        0            0           1              0         0
# 13273        71.0        0            0           0              0         1
#
#        mixed
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
# ...      ...
# 13269      0
# 13270      0
# 13271      0
# 13272      0
# 13273      0
#
# [13274 rows x 16 columns]
